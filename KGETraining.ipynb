# %%
from KGEkeras.models import ComplEx

# %%
from rdflib import Graph, URIRef, Literal

import numpy as np

# %%
from KGEkeras.models import DistMult, HolE, TransE, ComplEx, HAKE, ConvE, ModE, ConvR, ConvKB, RotatE, pRotatE
import numpy as np
import tensorflow as tf
from random import choice, choices
from collections import defaultdict

from tensorflow.keras.layers import Input 
from tqdm import tqdm
from tensorflow.keras.callbacks import Callback, EarlyStopping
from tensorflow.keras.losses import hinge, binary_crossentropy

from tensorflow.keras.models import Model

from KGEkeras.utils import load_kg, validate, loss_function_lookup, generate_negative, oversample_data

models = {'DistMult':DistMult,
           'TransE':TransE,
           'HolE':HolE,
           'ComplEx':ComplEx,
           'ConvE':ConvE,
            'ConvR':ConvR,
             'HAKE':HAKE,
             'RotatE':RotatE,
             'pRotatE':pRotatE
         }

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, kg, ns=10, batch_size=32, shuffle=True):
        self.batch_size = min(batch_size,len(kg))
        self.kg = kg
        self.ns = ns
        self.num_e = len(set([s for s,_,_ in kg])|set([o for _,_,o in kg]))
        self.shuffle = shuffle
        self.indices = list(range(len(kg)))
        
        self.on_epoch_end()

    def __len__(self):
        return len(self.kg) // self.batch_size

    def __getitem__(self, index):
        index = self.index[index * self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        
        X, y = self.__get_data(batch)
        return X, y

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def __get_data(self, batch):
        tmp_kg = np.asarray([self.kg[i] for i in batch])
        
        negative_kg = generate_negative(tmp_kg,N=self.num_e,negative=self.ns)
        X = oversample_data(kgs=[tmp_kg,negative_kg])
    
        return X, None 

def build_model(hp):
    
    params = hp.copy()
    params['e_dim'] = params['dim']
    params['r_dim'] = params['dim']
    params['name'] = 'embedding_model'
    
    embedding_model = models[params['embedding_model']]
    embedding_model = embedding_model(**params)
    triple = Input((3,))
    ftriple = Input((3,))
    
    inputs = [triple, ftriple]
    
    score = embedding_model(triple)
    fscore = embedding_model(ftriple)
    
    loss_function = loss_function_lookup(params['loss_function'])
    loss = loss_function(score,fscore,params['margin'] or 1, 1)
    
    model = Model(inputs=inputs, outputs=loss)
    model.add_loss(loss)
    
    model.compile(optimizer='adam',
                  loss=None)
    
    return model

def pad(kg,bs):
    while len(kg) % bs != 0:
        kg.append(choice(kg))
    return kg

# %%
g = Graph()
g.load('../TERA_OUTPUT/ecotox_taxonomy.nt',format='nt')
for s,p,o in g:
    if isinstance(o,Literal):
        g.remove((s,p,o))
entities = set(g.subjects()) | set(g.objects())
entities = [str(s) for s in entities if isinstance(s,URIRef)]

relations = set(g.predicates())
relations = [str(s) for s in relations if isinstance(s,URIRef)]

entity_mapping = dict(zip(entities,range(len(entities))))
relation_mapping = dict(zip(relations,range(len(relations))))


train_triples = np.asarray([(entity_mapping[str(s)],
                  relation_mapping[str(p)],
                  entity_mapping[str(o)]) for s,p,o in g])

# %%
from sklearn.model_selection import KFold

bs = 2048

config = {'num_entities':len(entities),
          'num_relations':len(relations),
          'dim':100,
          'embedding_model':'ComplEx',
          'loss_function':'pairwize_hinge',
          'margin':1}

for fold, (train_idx,test_idx) in enumerate(KFold(5).split(train_triples)):
    
    model = build_model(config)
    
    model.fit(DataGenerator(train_triples[train_idx],batch_size=bs),
             validation_data=DataGenerator(train_triples[test_idx],batch_size=bs),
             callbacks = [tf.keras.callbacks.EarlyStopping('val_loss',patience=5)],
             epochs=100,
             verbose=1)
    
    model.save_weights(f'tmp/model_weights_{fold}.tf')
    W = model.layers[1].entity_embedding.weights[0].numpy()
    np.save(f'tmp/model_entities_{fold}.npy',W)
# Out:
# Epoch 1/100
# 45/45 [==============================] - 86s 2s/step - loss: 1.0000 - val_loss: 0.9999
# Epoch 2/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.9988 - val_loss: 0.9909
# Epoch 3/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.9733 - val_loss: 0.9078
# Epoch 4/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.8113 - val_loss: 0.6287
# Epoch 5/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.4783 - val_loss: 0.4372
# Epoch 6/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.2963 - val_loss: 0.3257
# Epoch 7/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.2235 - val_loss: 0.2666
# Epoch 8/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.1517 - val_loss: 0.2261
# Epoch 9/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0933 - val_loss: 0.1963
# Epoch 10/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0522 - val_loss: 0.1756
# Epoch 11/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0270 - val_loss: 0.1638
# Epoch 12/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0146 - val_loss: 0.1580
# Epoch 13/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0088 - val_loss: 0.1547
# Epoch 14/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0068 - val_loss: 0.1513
# Epoch 15/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0058 - val_loss: 0.1519
# Epoch 16/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0054 - val_loss: 0.1501
# Epoch 17/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0048 - val_loss: 0.1499
# Epoch 18/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0045 - val_loss: 0.1489
# Epoch 19/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0041 - val_loss: 0.1482
# Epoch 20/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0039 - val_loss: 0.1474
# Epoch 21/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0037 - val_loss: 0.1480
# Epoch 22/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0033 - val_loss: 0.1481
# Epoch 23/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0031 - val_loss: 0.1483
# Epoch 24/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0029 - val_loss: 0.1477
# Epoch 25/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0028 - val_loss: 0.1476
# Epoch 1/100
# 45/45 [==============================] - 83s 2s/step - loss: 1.0000 - val_loss: 0.9999
# Epoch 2/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.9989 - val_loss: 0.9915
# Epoch 3/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.9746 - val_loss: 0.9140
# Epoch 4/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.8217 - val_loss: 0.6538
# Epoch 5/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.4989 - val_loss: 0.4805
# Epoch 6/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.3081 - val_loss: 0.3572
# Epoch 7/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.2303 - val_loss: 0.2951
# Epoch 8/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.1625 - val_loss: 0.2481
# Epoch 9/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.1022 - val_loss: 0.2134
# Epoch 10/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0575 - val_loss: 0.1926
# Epoch 11/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0303 - val_loss: 0.1787
# Epoch 12/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0161 - val_loss: 0.1703
# Epoch 13/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0093 - val_loss: 0.1656
# Epoch 14/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0067 - val_loss: 0.1635
# Epoch 15/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0059 - val_loss: 0.1630
# Epoch 16/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0052 - val_loss: 0.1613
# Epoch 17/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0047 - val_loss: 0.1582
# Epoch 18/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0045 - val_loss: 0.1606
# Epoch 19/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0041 - val_loss: 0.1593
# Epoch 20/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0037 - val_loss: 0.1598
# Epoch 21/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0035 - val_loss: 0.1595
# Epoch 22/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0033 - val_loss: 0.1585
# Epoch 1/100
# 45/45 [==============================] - 85s 2s/step - loss: 1.0000 - val_loss: 0.9999
# Epoch 2/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.9989 - val_loss: 0.9915
# Epoch 3/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.9741 - val_loss: 0.9108
# Epoch 4/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.8138 - val_loss: 0.6335
# Epoch 5/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.4803 - val_loss: 0.4372
# Epoch 6/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.2944 - val_loss: 0.3252
# Epoch 7/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.2163 - val_loss: 0.2653
# Epoch 8/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.1468 - val_loss: 0.2187
# Epoch 9/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0881 - val_loss: 0.1870
# Epoch 10/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0473 - val_loss: 0.1656
# Epoch 11/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0245 - val_loss: 0.1550
# Epoch 12/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0133 - val_loss: 0.1479
# Epoch 13/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0089 - val_loss: 0.1435
# Epoch 14/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0074 - val_loss: 0.1422
# Epoch 15/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0066 - val_loss: 0.1416
# Epoch 16/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0059 - val_loss: 0.1406
# Epoch 17/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0056 - val_loss: 0.1398
# Epoch 18/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0051 - val_loss: 0.1401
# Epoch 19/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0047 - val_loss: 0.1383
# Epoch 20/100
# 45/45 [==============================] - 86s 2s/step - loss: 0.0044 - val_loss: 0.1399
# Epoch 21/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0041 - val_loss: 0.1390
# Epoch 22/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0038 - val_loss: 0.1396
# Epoch 23/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0035 - val_loss: 0.1381
# Epoch 24/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0034 - val_loss: 0.1378
# Epoch 25/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0031 - val_loss: 0.1396
# Epoch 26/100
# 45/45 [==============================] - 87s 2s/step - loss: 0.0030 - val_loss: 0.1379
# Epoch 27/100
# 45/45 [==============================] - 85s 2s/step - loss: 0.0028 - val_loss: 0.1403
# Epoch 28/100
# 45/45 [==============================] - 84s 2s/step - loss: 0.0025 - val_loss: 0.1389
# Epoch 29/100
# 45/45 [==============================] - 83s 2s/step - loss: 0.0023 - val_loss: 0.1386
# Epoch 1/100
# 45/45 [==============================] - 82s 2s/step - loss: 1.0000 - val_loss: 0.9998
# Epoch 2/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.9988 - val_loss: 0.9910
# Epoch 3/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.9730 - val_loss: 0.9107
# Epoch 4/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.8126 - val_loss: 0.6397
# Epoch 5/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.4839 - val_loss: 0.4496
# Epoch 6/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.2974 - val_loss: 0.3301
# Epoch 7/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.2218 - val_loss: 0.2681
# Epoch 8/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.1489 - val_loss: 0.2222
# Epoch 9/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0909 - val_loss: 0.1889
# Epoch 10/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0488 - val_loss: 0.1685
# Epoch 11/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0252 - val_loss: 0.1545
# Epoch 12/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0142 - val_loss: 0.1476
# Epoch 13/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0090 - val_loss: 0.1449
# Epoch 14/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0073 - val_loss: 0.1448
# Epoch 15/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0065 - val_loss: 0.1421
# Epoch 16/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0060 - val_loss: 0.1414
# Epoch 17/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0056 - val_loss: 0.1409
# Epoch 18/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0050 - val_loss: 0.1399
# Epoch 19/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0046 - val_loss: 0.1402
# Epoch 20/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0044 - val_loss: 0.1405
# Epoch 21/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0040 - val_loss: 0.1391
# Epoch 22/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0038 - val_loss: 0.1387
# Epoch 23/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0036 - val_loss: 0.1397
# Epoch 24/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0033 - val_loss: 0.1380
# Epoch 25/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0031 - val_loss: 0.1397
# Epoch 26/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0029 - val_loss: 0.1390
# Epoch 27/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0028 - val_loss: 0.1386
# Epoch 28/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0024 - val_loss: 0.1389
# Epoch 29/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0024 - val_loss: 0.1378
# Epoch 30/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0022 - val_loss: 0.1375
# Epoch 31/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0021 - val_loss: 0.1381
# Epoch 32/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0019 - val_loss: 0.1380
# Epoch 33/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0018 - val_loss: 0.1387
# Epoch 34/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0017 - val_loss: 0.1376
# Epoch 35/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0016 - val_loss: 0.1357
# Epoch 36/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0015 - val_loss: 0.1376
# Epoch 37/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0014 - val_loss: 0.1372
# Epoch 38/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0013 - val_loss: 0.1379
# Epoch 39/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0012 - val_loss: 0.1368
# Epoch 40/100
# 45/45 [==============================] - 82s 2s/step - loss: 0.0012 - val_loss: 0.1371
# Epoch 1/100
# 45/45 [==============================] - 82s 2s/step - loss: 1.0000 - val_loss: 0.9998
# Epoch 2/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.9987 - val_loss: 0.9904
# Epoch 3/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.9716 - val_loss: 0.9062
# Epoch 4/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.8068 - val_loss: 0.6344
# Epoch 5/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.4761 - val_loss: 0.4476
# Epoch 6/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.2979 - val_loss: 0.3370
# Epoch 7/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.2245 - val_loss: 0.2759
# Epoch 8/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.1518 - val_loss: 0.2295
# Epoch 9/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0938 - val_loss: 0.1960
# Epoch 10/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0516 - val_loss: 0.1767
# Epoch 11/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0265 - val_loss: 0.1638
# Epoch 12/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0148 - val_loss: 0.1560
# Epoch 13/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0092 - val_loss: 0.1526
# Epoch 14/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0072 - val_loss: 0.1495
# Epoch 15/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0063 - val_loss: 0.1494
# Epoch 16/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0055 - val_loss: 0.1488
# Epoch 17/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0053 - val_loss: 0.1467
# Epoch 18/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0047 - val_loss: 0.1467
# Epoch 19/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0044 - val_loss: 0.1455
# Epoch 20/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0041 - val_loss: 0.1465
# Epoch 21/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0039 - val_loss: 0.1464
# Epoch 22/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0036 - val_loss: 0.1470
# Epoch 23/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0034 - val_loss: 0.1466
# Epoch 24/100
# 45/45 [==============================] - 81s 2s/step - loss: 0.0031 - val_loss: 0.1466
